# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install matplotlib
#!pip install pandas
#!pip install requests
# !pip install gmaps


# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key
# Out:
# Requirement already satisfied: gmaps in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (0.9.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.13.0)
# Requirement already satisfied: six in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (1.14.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (46.1.1.post20200323)
# Requirement already satisfied: jedi>=0.10 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.16.0)
# Requirement already satisfied: pickleshare in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.4)
# Requirement already satisfied: pygments in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (2.6.1)
# Requirement already satisfied: decorator in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: backcall in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.4)
# Requirement already satisfied: ipython-genutils in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: parso>=0.5.2 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.6.2)
# Requirement already satisfied: wcwidth in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.8)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-core in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: jupyter-client in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (18.1.1)
# Requirement already satisfied: Send2Trash in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: nbconvert in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: jinja2 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.7)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: testpath in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: defusedxml in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: bleach in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: webencodings in c:\users\apounds\appdata\local\continuum\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
data_location = "../WeatherPy/output_data/cities.csv"

weather_data = pd.read_csv(data_location)


weather_data
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0         Bouca          97      CF  1585663192        25   6.51
# 1          1       Mataura           7      NZ  1585663192        96 -46.19
# 2          2  Kaset Sombun           2      TH  1585663192        30  16.28
# 3          3       Kahului           1      US  1585663021        73  20.89
# 4          4      Cidreira          65      BR  1585663193        69 -30.18
# ..       ...           ...         ...     ...         ...       ...    ...
# 565      565     Esfarāyen          75      IR  1585663206        76  37.08
# 566      566        Bykovo          90      RU  1585663316        86  55.64
# 567      567   Subtanjalla          99      PE  1585663316        30 -14.02
# 568      568        Aitape         100      PG  1585663316        84  -3.14
# 569      569  Edwardsville          75      US  1585663316        76  38.81
#
#         Lng  Max Temp  Wind Speed
# 0     18.27     96.53        5.88
# 1    168.86     53.01        1.01
# 2    101.95     89.26        3.58
# 3   -156.47     71.60        5.82
# 4    -50.21     79.36       11.03
# ..      ...       ...         ...
# 565   57.51     48.20        4.70
# 566   38.08     28.99       15.66
# 567  -75.76     73.00        3.36
# 568  142.35     79.09        6.96
# 569  -89.95     52.00        4.70
#
# [570 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

locations = weather_data[["Lat", "Lng"]].astype(float)

fig = gmaps.figure()

# Create a poverty Heatmap layer
heat_layer = gmaps.heatmap_layer(locations, weights=weather_data["Humidity"], 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3)

fig.add_layer(heat_layer)



fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Criteria
# Max Temp lower than 80, but higher than 70
# Wind Speed less than 10
# Zero Cloudiness


nice_weather = weather_data[weather_data["Max Temp"]<=80]
nice_weather = nice_weather[nice_weather["Max Temp"]>=70]
nice_weather = nice_weather[nice_weather["Wind Speed"]<=10]
nice_weather = nice_weather[nice_weather["Cloudiness"]==0]
nice_weather = nice_weather.dropna()
nice_weather
# Out:
#      City_ID             City  Cloudiness Country        Date  Humidity  \
# 71        71             Tura           0      IN  1585663211        24
# 225      225            Kafue           0      ZM  1585663249        50
# 338      338  Bandar-e Lengeh           0      IR  1585663273        54
# 347      347           Dingle           0      PH  1585663275        75
# 387      387         Sakaraha           0      MG  1585663283        41
# 394      394        Bhāndāria           0      BD  1585663284        39
# 474      474         Moranbah           0      AU  1585663299        73
# 544      544              Sur           0      OM  1585663312        67
#
#        Lat     Lng  Max Temp  Wind Speed
# 71   25.52   90.22     72.23        2.19
# 225 -15.77   28.18     77.63        5.30
# 338  26.56   54.88     78.80        9.17
# 347  11.00  122.67     79.00        6.85
# 387 -22.90   44.53     77.74        4.83
# 394  22.49   90.06     78.69        5.30
# 474 -22.00  148.05     70.05        7.29
# 544  22.57   59.53     75.06        4.29

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = nice_weather.copy()

hotel_df.loc[:,"Coordinates"] = hotel_df.loc[:,"Lat"].astype(str) +"," + hotel_df.loc[:,"Lng"].astype(str)

hotel_df
# Out:
#      City_ID             City  Cloudiness Country        Date  Humidity  \
# 71        71             Tura           0      IN  1585663211        24
# 225      225            Kafue           0      ZM  1585663249        50
# 338      338  Bandar-e Lengeh           0      IR  1585663273        54
# 347      347           Dingle           0      PH  1585663275        75
# 387      387         Sakaraha           0      MG  1585663283        41
# 394      394        Bhāndāria           0      BD  1585663284        39
# 474      474         Moranbah           0      AU  1585663299        73
# 544      544              Sur           0      OM  1585663312        67
#
#        Lat     Lng  Max Temp  Wind Speed   Coordinates
# 71   25.52   90.22     72.23        2.19   25.52,90.22
# 225 -15.77   28.18     77.63        5.30  -15.77,28.18
# 338  26.56   54.88     78.80        9.17   26.56,54.88
# 347  11.00  122.67     79.00        6.85   11.0,122.67
# 387 -22.90   44.53     77.74        4.83   -22.9,44.53
# 394  22.49   90.06     78.69        5.30   22.49,90.06
# 474 -22.00  148.05     70.05        7.29  -22.0,148.05
# 544  22.57   59.53     75.06        4.29   22.57,59.53

# %%
target_radius = 5000
target_type = "hotel"
target_search = "hotel"

hotel_list = []

for location in hotel_df["Coordinates"]:
    params = {
        "location": location,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }
    
    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params).json()
    try:
        hotel_list.append(response["results"][0]["name"])
    except:
        hotel_list.append("***None Found***")
        print(f"No hotels within 5000m of {location}, hotel noted as ***None Found***")

hotel_df["Hotel Name"] = hotel_list

hotel_df
# Out:
# No hotels within 5000m of 11.0,122.67, hotel noted as ***None Found***
#      City_ID             City  Cloudiness Country        Date  Humidity  \
# 71        71             Tura           0      IN  1585663211        24
# 225      225            Kafue           0      ZM  1585663249        50
# 338      338  Bandar-e Lengeh           0      IR  1585663273        54
# 347      347           Dingle           0      PH  1585663275        75
# 387      387         Sakaraha           0      MG  1585663283        41
# 394      394        Bhāndāria           0      BD  1585663284        39
# 474      474         Moranbah           0      AU  1585663299        73
# 544      544              Sur           0      OM  1585663312        67
#
#        Lat     Lng  Max Temp  Wind Speed   Coordinates  \
# 71   25.52   90.22     72.23        2.19   25.52,90.22
# 225 -15.77   28.18     77.63        5.30  -15.77,28.18
# 338  26.56   54.88     78.80        9.17   26.56,54.88
# 347  11.00  122.67     79.00        6.85   11.0,122.67
# 387 -22.90   44.53     77.74        4.83   -22.9,44.53
# 394  22.49   90.06     78.69        5.30   22.49,90.06
# 474 -22.00  148.05     70.05        7.29  -22.0,148.05
# 544  22.57   59.53     75.06        4.29   22.57,59.53
#
#                             Hotel Name
# 71                   Hotel Polo Orchid
# 225                  Chita Lodge Kafue
# 338                     Diplomat Hotel
# 347                   ***None Found***
# 387                          Le Buffet
# 394                  5 Star Rest House
# 474  Direct Hotels - Monterey Moranbah
# 544                    Sur Grand Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

markers = gmaps.marker_layer(locations, info_box_template)

fig.add_layer(markers)
fig

# Display Map
# Out:
# Figure(layout=FigureLayout(height='420px'))
