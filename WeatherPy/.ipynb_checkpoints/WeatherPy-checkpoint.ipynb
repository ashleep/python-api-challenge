# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install scipy
#!pip install citipy

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import requests

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Collecting citipy
#   Using cached citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559707 sha256=02f212aeaad875feb8d4f8a9d256abbee32fd0c3f7b9e9cdfb0c2fe532a2bd34
#   Stored in directory: c:\users\apounds\appdata\local\pip\cache\wheels\6d\df\5e\ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?q=" 
mid_url = "&units=imperial&appid="
i=0

#log on next kernel

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# set up list to hold response info
city_id = []
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_t = []
wind = []


i=0
for city in cities:
    worked = True
    weather_data = requests.get(base_url+city+mid_url+weather_api_key)
    weather_data = weather_data.json()  
    
    #append lists with city info
    try:
        city_name.append(weather_data["name"])
        city_id.append(i)
        cloudiness.append(weather_data["clouds"]["all"])
        country.append(weather_data["sys"]["country"])
        date.append(weather_data["dt"])
        humidity.append(weather_data["main"]["humidity"])
        lat.append(weather_data["coord"]["lat"])
        lng.append(weather_data["coord"]["lon"])
        max_t.append(weather_data["main"]["temp_max"])
        wind.append(weather_data["wind"]["speed"])
        worked = True
    except:
        print(f"{city} is not on the list and will be skipped!")
        worked = False
    
    
    #limit data pulls for code dev and testing
    #if i == 200:
        #break      
    
    if worked:
        
        #print log
        print(f"{i} : {city}")
        
        i+=1
        
        
        #add data to dataframe
        weather_df = pd.DataFrame({
            "City_ID":city_id, 
            "City":city_name,
            "Cloudiness":cloudiness,
            "Country":country,
            "Date":date,
            "Humidity":humidity,
            "Lat":lat,
            "Lng":lng,
            "Max Temp":max_t,
            "Wind Speed":wind
        })
    
#write data to csv
weather_df.to_csv(output_data_file, index=False)   

#print data frame
weather_df
# Out:
# 0 : bouca
# 1 : mataura
# 2 : kaset sombun
# 3 : kahului
# 4 : cidreira
# cheuskiny is not on the list and will be skipped!
# 5 : saskylakh
# 6 : abu dhabi
# 7 : vao
# 8 : rikitea
# 9 : puerto ayora
# 10 : dawson creek
# 11 : ushuaia
# 12 : fortuna
# 13 : lavrentiya
# 14 : cape town
# 15 : maltahohe
# 16 : sault sainte marie
# 17 : rodrigues alves
# 18 : khatanga
# 19 : pisco
# 20 : carnarvon
# 21 : tasiilaq
# 22 : castro
# 23 : kutum
# 24 : new norfolk
# 25 : barrow
# 26 : laguna
# 27 : mount isa
# afmadu is not on the list and will be skipped!
# 28 : vaini
# 29 : point pleasant
# 30 : sinnamary
# 31 : georgetown
# 32 : norman wells
# 33 : copalillo
# 34 : chuy
# 35 : severo-kurilsk
# 36 : lebu
# 37 : talnakh
# 38 : bluff
# 39 : busselton
# 40 : carmen
# 41 : aksu
# 42 : avarua
# 43 : hithadhoo
# abiy adi is not on the list and will be skipped!
# 44 : lake havasu city
# 45 : bhanvad
# 46 : guerrero negro
# 47 : lancut
# 48 : vanimo
# 49 : geraldton
# 50 : hermanus
# 51 : tiksi
# 52 : lyuban
# 53 : chegdomyn
# 54 : nanortalik
# 55 : saint-philippe
# 56 : tigil
# 57 : san patricio
# 58 : braco do norte
# 59 : chapais
# 60 : camden
# 61 : bend
# 62 : torbay
# 63 : saldanha
# 64 : nantucket
# 65 : thompson
# 66 : nikolskoye
# 67 : boissevain
# 68 : vestmannaeyjar
# illoqqortoormiut is not on the list and will be skipped!
# 69 : port alfred
# 70 : souillac
# 71 : tura
# 72 : kerman
# 73 : pemba
# 74 : nsoko
# 75 : thinadhoo
# 76 : coihaique
# 77 : sidi ali
# 78 : pakxan
# taolanaro is not on the list and will be skipped!
# 79 : atuona
# 80 : kalmunai
# 81 : aklavik
# 82 : taiyuan
# 83 : the valley
# 84 : cockburn town
# 85 : karratha
# 86 : tehri
# 87 : port lincoln
# 88 : saint george
# 89 : kenai
# amderma is not on the list and will be skipped!
# 90 : punta arenas
# 91 : iqaluit
# 92 : aswan
# 93 : hobart
# 94 : butaritari
# attawapiskat is not on the list and will be skipped!
# 95 : bredasdorp
# bataraza is not on the list and will be skipped!
# 96 : price
# 97 : kapaa
# 98 : almenara
# 99 : san ignacio
# 100 : airai
# 101 : sept-iles
# 102 : albany
# 103 : lagoa
# 104 : malinovskiy
# 105 : yabrud
# 106 : sitka
# 107 : weinan
# 108 : upernavik
# 109 : bengkulu
# 110 : port elizabeth
# 111 : whitehorse
# 112 : mount gambier
# 113 : lata
# 114 : aquin
# 115 : tortoli
# 116 : mwene-ditu
# 117 : menongue
# 118 : flinders
# tsihombe is not on the list and will be skipped!
# 119 : sao joaquim do monte
# 120 : codrington
# 121 : sao filipe
# 122 : byron bay
# 123 : bethel
# 124 : talaya
# 125 : hulja
# 126 : ponta do sol
# 127 : victoria
# 128 : sungaipenuh
# 129 : manavalakurichi
# 130 : tautira
# 131 : oer-erkenschwick
# 132 : bambous virieux
# 133 : takoradi
# 134 : richards bay
# 135 : constitucion
# 136 : juneau
# 137 : los llanos de aridane
# 138 : mandera
# 139 : bundaberg
# litoral del san juan is not on the list and will be skipped!
# 140 : sabang
# 141 : taltal
# 142 : tuktoyaktuk
# mys shmidta is not on the list and will be skipped!
# 143 : ancud
# 144 : nagato
# 145 : dikson
# 146 : namatanai
# 147 : hwange
# sentyabrskiy is not on the list and will be skipped!
# 148 : tecoanapa
# jiddah is not on the list and will be skipped!
# 149 : shahr-e babak
# 150 : stokmarknes
# 151 : college
# 152 : clyde river
# 153 : meulaboh
# 154 : alamosa
# 155 : humaita
# 156 : husavik
# 157 : simbahan
# 158 : tual
# satitoa is not on the list and will be skipped!
# 159 : talcahuano
# 160 : faanui
# 161 : san rafael
# 162 : yellowknife
# 163 : ordzhonikidze
# 164 : sunam
# 165 : yueyang
# 166 : tabou
# 167 : gobabis
# barentsburg is not on the list and will be skipped!
# 168 : portland
# 169 : hamilton
# 170 : olafsvik
# 171 : el alto
# 172 : areosa
# 173 : vodnyy
# 174 : bandarbeyla
# 175 : auki
# 176 : luganville
# 177 : tuatapere
# samusu is not on the list and will be skipped!
# 178 : ambon
# belushya guba is not on the list and will be skipped!
# 179 : pangody
# 180 : luau
# 181 : ahuimanu
# 182 : asgabat
# 183 : marabba
# 184 : egvekinot
# 185 : uralets
# 186 : kodiak
# 187 : arraial do cabo
# 188 : angoche
# 189 : pandamatenga
# 190 : avera
# 191 : yenagoa
# 192 : guanica
# 193 : hambantota
# 194 : ixtapa
# 195 : birjand
# saleaula is not on the list and will be skipped!
# 196 : east london
# 197 : kaka
# 198 : yaan
# 199 : sunrise manor
# 200 : malanje
# 201 : itacarambi
# 202 : cherskiy
# 203 : katherine
# 204 : port keats
# 205 : bhayavadar
# 206 : tessalit
# 207 : hami
# 208 : asau
# 209 : grand-lahou
# 210 : saint-pierre
# 211 : cabo san lucas
# 212 : coahuayana
# gulshat is not on the list and will be skipped!
# 213 : port hardy
# 214 : mishelevka
# 215 : baherden
# 216 : nizhnevartovsk
# 217 : nampula
# jiroft is not on the list and will be skipped!
# 218 : qaanaaq
# 219 : taua
# 220 : biltine
# 221 : san ramon
# 222 : cayenne
# 223 : carman
# 224 : eichenzell
# 225 : kafue
# 226 : kirakira
# 227 : krasnoye
# 228 : siyabuswa
# 229 : nova vicosa
# 230 : solnechnyy
# 231 : lorengau
# 232 : honningsvag
# 233 : kosh-agach
# grand river south east is not on the list and will be skipped!
# 234 : hofn
# 235 : bilibino
# 236 : hilo
# 237 : leningradskiy
# umm durman is not on the list and will be skipped!
# 238 : beringovskiy
# 239 : terra santa
# 240 : marawi
# 241 : rabak
# 242 : kaeo
# 243 : isangel
# 244 : dubbo
# 245 : blyth
# 246 : mandali
# 247 : kashi
# 248 : izacic
# 249 : jalu
# umzimvubu is not on the list and will be skipped!
# 250 : tezu
# 251 : poum
# 252 : palu
# 253 : ayagoz
# 254 : caravelas
# 255 : berdigestyakh
# 256 : mar del plata
# 257 : jamestown
# 258 : kazachinskoye
# 259 : progreso
# 260 : zyryanka
# 261 : chokurdakh
# 262 : prince rupert
# 263 : dalby
# 264 : sistranda
# 265 : gboko
# 266 : klaksvik
# 267 : verkhnetulomskiy
# 268 : christchurch
# 269 : kavieng
# 270 : zhezkazgan
# 271 : tabory
# wahran is not on the list and will be skipped!
# 272 : longyearbyen
# khonuu is not on the list and will be skipped!
# 273 : saint anthony
# 274 : cerrito
# 275 : evensk
# 276 : punta gorda
# 277 : kavaratti
# nizhneyansk is not on the list and will be skipped!
# 278 : usinsk
# 279 : khandyga
# 280 : xining
# 281 : steinbach
# 282 : chipinge
# 283 : hays
# 284 : salamiyah
# 285 : dakar
# 286 : porbandar
# bolshaya chernigovka is not on the list and will be skipped!
# 287 : te anau
# 288 : port augusta
# 289 : vicuna
# 290 : kepno
# 291 : port moresby
# 292 : raga
# tumannyy is not on the list and will be skipped!
# 293 : padang
# 294 : lander
# 295 : henties bay
# 296 : hastings
# palabuhanratu is not on the list and will be skipped!
# 297 : honiara
# 298 : sri aman
# 299 : baykit
# 300 : ribeira grande
# 301 : ponta delgada
# 302 : anadyr
# 303 : safaga
# 304 : kirillov
# 305 : mahebourg
# barawe is not on the list and will be skipped!
# 306 : katangli
# 307 : sobolevo
# 308 : crossville
# 309 : kajaani
# 310 : awbari
# 311 : mugango
# 312 : keetmanshoop
# 313 : esperance
# 314 : clarence town
# 315 : lompoc
# 316 : nabire
# 317 : zheleznodorozhnyy
# 318 : vila franca do campo
# 319 : shitanjing
# 320 : corrente
# 321 : calama
# 322 : provideniya
# 323 : cootamundra
# uwayl is not on the list and will be skipped!
# 324 : vestmanna
# 325 : aktau
# 326 : suicheng
# 327 : kapuskasing
# 328 : tambopata
# 329 : esso
# 330 : ostrovnoy
# 331 : zelenogradsk
# 332 : luchegorsk
# 333 : vila velha
# dipkarpaz is not on the list and will be skipped!
# 334 : hasaki
# 335 : kaitangata
# 336 : beloha
# 337 : bambanglipuro
# 338 : bandar-e lengeh
# 339 : manacapuru
# 340 : north bend
# 341 : nenjiang
# 342 : cabinda
# 343 : chebsara
# 344 : naze
# 345 : kruisfontein
# 346 : barsovo
# 347 : dingle
# 348 : punta alta
# 349 : pacific grove
# 350 : kifri
# lolua is not on the list and will be skipped!
# 351 : ust-kuyga
# 352 : sao gabriel da cachoeira
# 353 : berlevag
# 354 : namibe
# 355 : camana
# 356 : kupang
# 357 : tiarei
# 358 : donghai
# 359 : fujin
# 360 : naryan-mar
# 361 : nishihara
# tawnat is not on the list and will be skipped!
# 362 : taksimo
# 363 : kota belud
# 364 : eslov
# 365 : townsville
# 366 : pozo colorado
# 367 : marshall
# 368 : san quintin
# toliary is not on the list and will be skipped!
# 369 : mahenge
# 370 : ust-nera
# 371 : kualakapuas
# 372 : kalia
# 373 : lengshuitan
# 374 : maumere
# 375 : seminole
# vaitupu is not on the list and will be skipped!
# 376 : kandi
# 377 : provost
# 378 : comodoro rivadavia
# 379 : waipawa
# 380 : copacabana
# 381 : vardo
# 382 : bonanza
# 383 : maloy
# 384 : luderitz
# 385 : coachella
# 386 : san cristobal
# 387 : sakaraha
# 388 : adrar
# 389 : godo
# 390 : half moon bay
# 391 : sao felix do xingu
# 392 : barra dos coqueiros
# khormuj is not on the list and will be skipped!
# 393 : obo
# 394 : bhandaria
# 395 : hualmay
# 396 : ilulissat
# 397 : miraflores
# 398 : dhidhdhoo
# 399 : helong
# 400 : ubinskoye
# 401 : hovd
# 402 : alugan
# 403 : jumla
# 404 : shenjiamen
# 405 : obuasi
# 406 : palmer
# 407 : murchison
# 408 : mamallapuram
# 409 : suhut
# 410 : kralendijk
# 411 : katsuura
# 412 : shirokiy
# 413 : namwala
# 414 : mackay
# 415 : qandala
# 416 : clarksville
# 417 : olovyannaya
# ijaki is not on the list and will be skipped!
# 418 : salalah
# 419 : baraboo
# 420 : shingu
# 421 : krasnoselkup
# 422 : lixourion
# 423 : thetford mines
# 424 : rocha
# 425 : turan
# 426 : high level
# 427 : abu samrah
# kadykchan is not on the list and will be skipped!
# 428 : batagay-alyta
# 429 : plettenberg bay
# 430 : ayorou
# 431 : nemuro
# 432 : iki-burul
# 433 : grande prairie
# 434 : antalaha
# 435 : sioux lookout
# 436 : labuhan
# 437 : touros
# 438 : korem
# 439 : roma
# 440 : kloulklubed
# 441 : ust-kulom
# 442 : peace river
# 443 : tabivere
# 444 : leh
# 445 : asfi
# 446 : hudson bay
# 447 : andenes
# 448 : pontes e lacerda
# warqla is not on the list and will be skipped!
# 449 : belaya gora
# 450 : hickory
# 451 : rovaniemi
# 452 : clifton
# 453 : quelimane
# kachikau is not on the list and will be skipped!
# 454 : pevek
# 455 : ribeira brava
# 456 : ilovlya
# lushunkou is not on the list and will be skipped!
# 457 : cavalcante
# 458 : buta
# 459 : taungdwingyi
# 460 : port-cartier
# 461 : odweyne
# 462 : beyneu
# 463 : gopalganj
# meyungs is not on the list and will be skipped!
# 464 : santa rosa
# 465 : parana
# 466 : la ronge
# 467 : port-gentil
# 468 : wamba
# 469 : iralaya
# 470 : caxito
# geresk is not on the list and will be skipped!
# 471 : arlit
# 472 : chicama
# 473 : mongoumba
# 474 : moranbah
# 475 : otofuke
# 476 : matara
# 477 : umea
# 478 : vavuniya
# 479 : kingaroy
# skagastrond is not on the list and will be skipped!
# 480 : yulara
# 481 : papetoai
# 482 : mogadishu
# 483 : awjilah
# 484 : fairbanks
# 485 : juegang
# 486 : sangar
# 487 : imbituba
# 488 : zhumadian
# 489 : aripuana
# 490 : kaffrine
# 491 : murgab
# 492 : havelock
# 493 : tiznit
# 494 : aviles
# 495 : mocuba
# 496 : mutis
# 497 : cadereyta
# 498 : vostok
# 499 : churapcha
# 500 : rabo de peixe
# 501 : kagadi
# 502 : catuday
# karauzyak is not on the list and will be skipped!
# 503 : mbaiki
# falealupo is not on the list and will be skipped!
# 504 : tomatlan
# 505 : xiangfan
# 506 : sisimiut
# 507 : samarai
# 508 : ploemeur
# 509 : rancho palos verdes
# 510 : estelle
# 511 : ipubi
# 512 : bubaque
# 513 : chimoio
# 514 : krasnyy yar
# sinkat is not on the list and will be skipped!
# 515 : shaoyang
# 516 : guatire
# 517 : ngawi
# 518 : tevriz
# 519 : solton
# 520 : lagos
# 521 : leua
# marcona is not on the list and will be skipped!
# 522 : qasigiannguit
# 523 : sylacauga
# 524 : hay river
# 525 : carbonia
# 526 : panaba
# 527 : lamar
# 528 : ballina
# 529 : vila
# 530 : hervey bay
# 531 : lakes entrance
# 532 : diffa
# 533 : san matias
# 534 : morehead
# 535 : dolores
# 536 : mayo
# 537 : nome
# 538 : maniitsoq
# 539 : rio gallegos
# 540 : riyadh
# 541 : buluang
# 542 : poquoson
# 543 : havre-saint-pierre
# 544 : sur
# 545 : prachuap khiri khan
# 546 : san juan del sur
# 547 : giddalur
# 548 : muroto
# 549 : rio grande
# 550 : acapulco
# 551 : bosaso
# 552 : yarkovo
# 553 : muros
# 554 : luzhou
# 555 : tamandare
# 556 : north platte
# 557 : marataizes
# 558 : batemans bay
# 559 : sonderso
# 560 : clinton
# 561 : ranot
# 562 : lososina
# 563 : ukiah
# 564 : george town
# 565 : esfarayen
# 566 : bykovo
# 567 : subtanjalla
# 568 : aitape
# 569 : edwardsville
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0         Bouca          97      CF  1585663192        25   6.51
# 1          1       Mataura           7      NZ  1585663192        96 -46.19
# 2          2  Kaset Sombun           2      TH  1585663192        30  16.28
# 3          3       Kahului           1      US  1585663021        73  20.89
# 4          4      Cidreira          65      BR  1585663193        69 -30.18
# ..       ...           ...         ...     ...         ...       ...    ...
# 565      565     Esfarāyen          75      IR  1585663206        76  37.08
# 566      566        Bykovo          90      RU  1585663316        86  55.64
# 567      567   Subtanjalla          99      PE  1585663316        30 -14.02
# 568      568        Aitape         100      PG  1585663316        84  -3.14
# 569      569  Edwardsville          75      US  1585663316        76  38.81
#
#         Lng  Max Temp  Wind Speed
# 0     18.27     96.53        5.88
# 1    168.86     53.01        1.01
# 2    101.95     89.26        3.58
# 3   -156.47     71.60        5.82
# 4    -50.21     79.36       11.03
# ..      ...       ...         ...
# 565   57.51     48.20        4.70
# 566   38.08     28.99       15.66
# 567  -75.76     73.00        3.36
# 568  142.35     79.09        6.96
# 569  -89.95     52.00        4.70
#
# [570 rows x 10 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#get specific date for printing
from datetime import date
today = date.today()


plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker = "o", facecolor="red", edgecolors="black")
plt.title(f"City Latitude vs. Temperature ({today})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(color="grey")
plt.savefig("output_data/LatitudeVsTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker = "o", facecolor="red", edgecolors="black")
plt.title(f"City Latitude vs. Humidity ({today})")
plt.xlabel("Latitude")
plt.ylabel("Humididty (%)")
plt.grid(color="grey")
plt.savefig("output_data/LatitudeVsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker = "o", facecolor="red", edgecolors="black")
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(color="grey")
plt.savefig("output_data/LatitudeVsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker = "o", facecolor="red", edgecolors="black")
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(color="grey")
plt.savefig("output_data/LatitudeVsWind Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linregplot(xaxis, yaxis, xlabel, ylabel, title, location):
    m_slope, m_int, m_r, m_p, m_std_err = linregress(xaxis, yaxis, )
    m_fit = m_slope * xaxis + m_int
    plt.scatter(xaxis, yaxis)
    plt.plot(xaxis,m_fit,"--")
    plt.xticks(xaxis, rotation=90)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    if location == "N":
        plt.xticks(np.arange(0, 91, step=30))
    else:
        plt.xticks(np.arange(-90, 0, step=30))
        
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_df = weather_df[weather_df["Lat"]>=0]
southern_df = weather_df[weather_df["Lat"]<0]

northern_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0         Bouca          97      CF  1585663192        25   6.51
# 2          2  Kaset Sombun           2      TH  1585663192        30  16.28
# 3          3       Kahului           1      US  1585663021        73  20.89
# 5          5     Saskylakh         100      RU  1585663193        89  71.92
# 6          6     Abu Dhabi           0      AE  1585663150        47  24.47
# ..       ...           ...         ...     ...         ...       ...    ...
# 563      563         Ukiah          90      US  1585663143        87  39.15
# 564      564   George Town          20      MY  1585663315        79   5.41
# 565      565     Esfarāyen          75      IR  1585663206        76  37.08
# 566      566        Bykovo          90      RU  1585663316        86  55.64
# 569      569  Edwardsville          75      US  1585663316        76  38.81
#
#         Lng  Max Temp  Wind Speed
# 0     18.27     96.53        5.88
# 2    101.95     89.26        3.58
# 3   -156.47     71.60        5.82
# 5    114.08     -5.26       11.21
# 6     54.37     78.80       19.46
# ..      ...       ...         ...
# 563 -123.21     53.01        2.21
# 564  100.34     86.00        4.70
# 565   57.51     48.20        4.70
# 566   38.08     28.99       15.66
# 569  -89.95     52.00        4.70
#
# [391 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linregplot(northern_df["Lat"], northern_df["Max Temp"],"Latitude","Max Temp (F)", "Northern Hemisphere - Max Temp vs. Latitude","N")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linregplot(southern_df["Lat"], southern_df["Max Temp"],"Latitude","Max Temp (F)", "Southern Hemisphere - Max Temp vs. Latitude","S")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linregplot(northern_df["Lat"], northern_df["Humidity"],"Latitude","Humidity (%)", "Northern Hemisphere - Humidity vs. Latitude","N")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linregplot(southern_df["Lat"], southern_df["Humidity"],"Latitude","Humidity (%)", "Southern Hemisphere - Humidity vs. Latitude","S")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linregplot(northern_df["Lat"], northern_df["Cloudiness"],"Latitude","Cloudiness (%)", "Northern Hemisphere - Cloudiness vs. Latitude","N")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linregplot(southern_df["Lat"], southern_df["Cloudiness"],"Latitude","Cloudiness (%)", "Southern Hemisphere - Cloudiness vs. Latitude","S")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linregplot(northern_df["Lat"], northern_df["Wind Speed"],"Latitude","Wind Speed (mph)", "Northern Hemisphere - Wind Speed vs. Latitude","N")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linregplot(southern_df["Lat"], southern_df["Wind Speed"],"Latitude","Wind Speed (mph)", "Southern Hemisphere - Wind Speed vs. Latitude","S")
